# %% [markdown]
# Testing the Doc Reader.py

# %%
import os

from modules.docReader import read_pdf, read_docx
from modules.textSplitter import split_documents
from modules.VectorStore import  addDocsToVectorStore,get_retriever
from utils.ConfigUtility import ConfigUtility

folderPath = '../Docs'


pdf_docs = read_docx(os.path.join(folderPath, 'abc_enterprise_travel_policy.docx'))

for doc in pdf_docs:
    print(doc.page_content[:50]+ '...')  # Print the first 50 characters of each PDF document

split_docs = split_documents(pdf_docs)

store = addDocsToVectorStore(split_docs)


ret = get_retriever(3)

docs =ret.invoke("How many total leaves are allowed in a year?")

for doc in docs:
    print(doc.page_content[:50]+ '...')  # Print the first 50 characters of each retrieved document

# %%
from modules.RagChain import build_chain
from modules.VectorStore import get_retriever





llm_chain = build_chain()
llm_chain.invoke(input={"question":"What are total number of leaves?",
                        "session_id": "test"}                      )
# while True:
#     ques = input("Enter Question")
#     if(ques == "quit"):
#         break
#     ans = llm_chain.invoke(
#             {   "question": "Give detailed explanation of Scikit-learn?"},
#     config = {"configurable": {"session_id": "abc"}},
#     )
#     print("Answer: {ans}")

# %%
from modules.BM25Retriever import BM25Retriever
from modules.docReader import load_all_docs
    
folderPath = '../Docs'
documents = load_all_docs(folderPath)

bm25Retriever = BM25Retriever(documents=documents)

results =bm25Retriever.get_top_k("What is the total enumeration", 2)

print(results)

# %%
from modules.RagChain import build_chain
from modules.VectorStore import get_retriever
from modules.chatMemory import llm_chain_with_memory

llm_chain = build_chain()
memory_chain = llm_chain_with_memory(llm_chain, enabled=True, recent_k=2)
resp1 = memory_chain.invoke(
    
     {   "question": "What are the total number of leaves?"},
      config={"configurable": {"session_id": "test_session_1"}})
print(resp1)
print("****************************************************************************")

response2 = memory_chain.invoke({"question":"As a Lead how much I can spend of hotel expenses during travel?"},
                       config={"configurable": {"session_id": "test_session_1"}})
print(response2)

print("****************************************************************************")

response3 = memory_chain.invoke({"question":"How many days I can expect for my expense reimbursement?"},
                       config={"configurable": {"session_id": "test_session_1"}})
print(response3)
# Out:
# e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.7.0) or chardet (7.6.0)/charset_normalizer (3.5.1) doesn't match a supported version!
#   warnings.warn(
# LLM Provider: openai
# LLM Model: gpt-4o
# Building chain with LLM provider: openai, model: gpt-4o
# Hybrid RAG chain built successfully with provider: openai
# Adding memory to chain for session: test_session_1
# e:\IITPatnaProjects\CapStoneProject\src\modules\chatMemory.py:23: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   SESSION_SUMMARY_MEMORY[session_id] = ConversationSummaryMemory(
# Retrieving hybrid results for query: What are the total number of leaves??
# Loading OpenAI embeddings...
# ****Using persist dir: e:\IITPatnaProjects\CapStoneProject\src\vectorestore\openai_faiss_index for vectore store
# Updating existing FAISS
# Vector store: <langchain_community.vectorstores.faiss.FAISS object at 0x000001C7B9C34860>
# using multi-query retriever
# Using LLM provider: openai for multi-query retriever
# Using FAISS retriever with top_k=5
# FAISS retrieved 5 documents for query: What are the total number of leaves??
# Loading documents from folder: e:\IITPatnaProjects\CapStoneProject\Docs
# Retrieving top BM25 matches 5 documents for query: What are the total number of leaves??
# BM25 retrieved 5 documents for query: What are the total number of leaves??
# Normalized FAISS scores: [1.   0.75 0.5  0.25 0.  ]
# Normalized BM25 scores: [1.         0.36945144 0.25283501 0.12422843 0.        ]
# Hybrid retrieved 5 documents for query: What are the total number of leaves??
# Generated context is [(Document(id='ce67ad0e-5e36-468f-8e1e-dcd55da40862', metadata={'page': 1, 'FileName': 'Docs\\abc_enterprise_leave_policy.pdf', 'chunk_index': 1}, page_content='operational continuity and adherence to statutory labor compliance. \n2. Leave Entitlements Summary\nLeave Category Annual\nQuota Accrual FrequencyKey Rules / Carry-Forward\nEarned / Privilege Leave\n(EL)\n18 Days 1.5 days / month Max 30 days carry-forward; encashable at\nseparation.\nCasual Leave (CL) 10 Days Credited annually\n(Jan 1)\nLapses at calendar year-end; cannot exceed 3\nconsecutive days.\nSick / Medical Leave\n(SL)\n8 Days Credited annually\n(Jan 1)\nRequires medical certificate if exceeding 2'), 0.6), (Document(metadata={'page': 2, 'FileName': 'e:\\IITPatnaProjects\\CapStoneProject\\Docs\\abc_enterprise_leave_policy.pdf'}, page_content='Note on Public Holidays: ABC Enterprise publishes an annual list of 10 mandatory and 2 optional (restricted) holidays at\nthe start of each calendar year. \n4. Leave Application & Approval Workflow\n1. Submission: Employee submits the leave request through the ABC Enterprise HR Portal / HRMS specifying\ndates and handover arrangements.\n2. Manager Review: Direct supervisor reviews the request within 48 business hours considering team coverage\nand project milestones.\n3. HR Record: Upon manager approval, the HRMS automatically updates the leave balance and notifies the payroll\ndepartment.\n5. General Terms & Non-Compliance\nUnplanned Absences: In emergencies, employees must notify their immediate supervisor via email or\nmessaging before 10:00 AM on the day of absence.\nLeave Without Pay (LWP): Leaves taken beyond accrued balances or without prior sanction will be classified as\nLWP, resulting in proportionate salary deduction.\nUnauthorized Absence: Continuous unnotified absence exceeding 5 consecutive working days will initiate\nstandard disciplinary procedures.\nPoC Disclaimer: This document is generated as a sample draft for evaluation and demonstration purposes for ABC\nEnterprise. \n• \n• \n• \nABC Enterprise • Corporate HR Policies • Strictly Internal Page 2 of 2'), 0.4), (Document(metadata={'paragraph': 18, 'FileName': 'e:\\IITPatnaProjects\\CapStoneProject\\Docs\\abc_enterprise_travel_policy.docx'}, page_content='1. Domestic Trips (< $1,500 total estimated spend): Requires immediate Line Manager approval.'), 0.30000000000000004), (Document(id='0728f90e-bed6-4947-938c-43a6e83610d8', metadata={'page': 1, 'FileName': 'Docs\\abc_enterprise_leave_policy.pdf', 'chunk_index': 1}, page_content='operational continuity and adherence to statutory labor compliance. \n2. Leave Entitlements Summary\nLeave Category Annual\nQuota Accrual FrequencyKey Rules / Carry-Forward\nEarned / Privilege Leave\n(EL)\n18 Days 1.5 days / month Max 30 days carry-forward; encashable at\nseparation.\nCasual Leave (CL) 10 Days Credited annually\n(Jan 1)\nLapses at calendar year-end; cannot exceed 3\nconsecutive days.\nSick / Medical Leave\n(SL)\n8 Days Credited annually\n(Jan 1)\nRequires medical certificate if exceeding 2'), 0.22167086271951708), (Document(metadata={'paragraph': 19, 'FileName': 'e:\\IITPatnaProjects\\CapStoneProject\\Docs\\abc_enterprise_travel_policy.docx'}, page_content='2. Domestic Trips (≥ $1,500 total spend): Requires Line Manager and Department Head (VP) approval.'), 0.20000000000000007)]
# content='Based on the retrieved context, the total number of leaves available annually at ABC Enterprise are as follows:\n\n1. **Earned/Privilege Leave (EL):** 18 days per year, accruing at 1.5 days per month.\n2. **Casual Leave (CL):** 10 days per year, credited annually.\n3. **Sick/Medical Leave (SL):** 8 days per year, credited annually.\n\nThis sums up to a total of 36 days of leave per year, excluding public holidays and any additional optional holidays.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 113, 'prompt_tokens': 824, 'total_tokens': 937, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_c9a0e786b8', 'id': 'chatcmpl-ELAKPMkEepjPzJ3HUeA3KtowM379R', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--0b5b786c-a47c-4a3b-8ef1-a66d3372aa54-0' usage_metadata={'input_tokens': 824, 'output_tokens': 113, 'total_tokens': 937, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ****************************************************************************
# Adding memory to chain for session: test_session_1
# Retrieving hybrid results for query: As a Lead how much I can spend of hotel expenses during travel??
# Loading OpenAI embeddings...
# ****Using persist dir: e:\IITPatnaProjects\CapStoneProject\src\vectorestore\openai_faiss_index for vectore store
# Updating existing FAISS
# Vector store: <langchain_community.vectorstores.faiss.FAISS object at 0x000001C82A02FAA0>
# using multi-query retriever
# Using LLM provider: openai for multi-query retriever
# Using FAISS retriever with top_k=5
# FAISS retrieved 7 documents for query: As a Lead how much I can spend of hotel expenses during travel??
# Loading documents from folder: e:\IITPatnaProjects\CapStoneProject\Docs
# Retrieving top BM25 matches 5 documents for query: As a Lead how much I can spend of hotel expenses during travel??
# BM25 retrieved 5 documents for query: As a Lead how much I can spend of hotel expenses during travel??
# Normalized FAISS scores: [1.         0.83333333 0.66666667 0.5        0.33333333 0.16666667
#  0.        ]
# Normalized BM25 scores: [1.         0.90176931 0.4709906  0.14533517 0.        ]
# Hybrid retrieved 5 documents for query: As a Lead how much I can spend of hotel expenses during travel??
# Generated context is [(Document(id='b175e53b-8a0e-43c8-aa65-c58d79aa315a', metadata={'paragraph': 18, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='1. Domestic Trips (< $1,500 total estimated spend): Requires immediate Line Manager approval.'), 0.6), (Document(id='f17b00c0-d7ca-4a79-b555-831d553506a5', metadata={'paragraph': 19, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='2. Domestic Trips (≥ $1,500 total spend): Requires Line Manager and Department Head (VP) approval.'), 0.541061588392129), (Document(id='0548b6a9-520b-421f-8457-46a6beda739b', metadata={'paragraph': 7, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='Employees traveling on official company assignments are entitled to transport and lodging arrangements based on job level and journey type:'), 0.4), (Document(id='3cf60e54-e49a-47c4-87e5-5eddc882db1b', metadata={'paragraph': 2, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='Business Travel Policy Manual'), 0.3333333333333333), (Document(id='652d2b38-7e94-493b-9ab8-681e92bd301d', metadata={'paragraph': 6, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='2. Travel Class & Accommodation Entitlements'), 0.28259435862279464)]
# content='Based on the retrieved context, there is no specific information provided regarding the exact amount a Lead can spend on hotel expenses during travel. It mentions that employees are entitled to transport and lodging arrangements based on job level and journey type, but does not specify amounts. For precise details on hotel expense limits, you may need to refer to the Business Travel Policy Manual or consult with your Line Manager or Department Head.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 661, 'total_tokens': 741, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_c9a0e786b8', 'id': 'chatcmpl-ELAKXGY6JC5Tt99WlCrRwSj7fy4k6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--e1715a6c-e5dc-4c74-9325-628f9a8ec576-0' usage_metadata={'input_tokens': 661, 'output_tokens': 80, 'total_tokens': 741, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ****************************************************************************
# Adding memory to chain for session: test_session_1
# Retrieving hybrid results for query: How many days I can expect for my expense reimbursement??
# Loading OpenAI embeddings...
# ****Using persist dir: e:\IITPatnaProjects\CapStoneProject\src\vectorestore\openai_faiss_index for vectore store
# Updating existing FAISS
# Vector store: <langchain_community.vectorstores.faiss.FAISS object at 0x000001C82A0A5EB0>
# using multi-query retriever
# Using LLM provider: openai for multi-query retriever
# Using FAISS retriever with top_k=5
# FAISS retrieved 6 documents for query: How many days I can expect for my expense reimbursement??
# Loading documents from folder: e:\IITPatnaProjects\CapStoneProject\Docs
# Retrieving top BM25 matches 5 documents for query: How many days I can expect for my expense reimbursement??
# BM25 retrieved 5 documents for query: How many days I can expect for my expense reimbursement??
# Normalized FAISS scores: [1.  0.8 0.6 0.4 0.2 0. ]
# Normalized BM25 scores: [1.         0.50432329 0.11290696 0.08462255 0.        ]
# Hybrid retrieved 5 documents for query: How many days I can expect for my expense reimbursement??
# Generated context is [(Document(id='4a4a2dee-b202-43d2-8770-006022c9a3da', metadata={'paragraph': 25, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='6. Expense Settlement & Reimbursement Timeline'), 0.6), (Document(id='b175e53b-8a0e-43c8-aa65-c58d79aa315a', metadata={'paragraph': 18, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='1. Domestic Trips (< $1,500 total estimated spend): Requires immediate Line Manager approval.'), 0.4), (Document(metadata={'paragraph': 25, 'FileName': 'e:\\IITPatnaProjects\\CapStoneProject\\Docs\\abc_enterprise_travel_policy.docx'}, page_content='6. Expense Settlement & Reimbursement Timeline'), 0.32000000000000006), (Document(id='449f098f-befe-4847-9e24-e48dcc68a4fb', metadata={'paragraph': 26, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='All expense claims must be filed within 15 calendar days following return from travel. Required documentation includes itemized receipts for any individual expense item over $25, boarding passes, and lodging invoices detailing room rates and taxes.'), 0.30259397250278197), (Document(metadata={'paragraph': 26, 'FileName': 'e:\\IITPatnaProjects\\CapStoneProject\\Docs\\abc_enterprise_travel_policy.docx'}, page_content='All expense claims must be filed within 15 calendar days following return from travel. Required documentation includes itemized receipts for any individual expense item over $25, boarding passes, and lodging invoices detailing room rates and taxes.'), 0.24)]
# content='Based on the retrieved context, you should file your expense claims within 15 calendar days following your return from travel. The reimbursement process would typically begin after you have submitted all the required documentation, including itemized receipts for expenses over $25, boarding passes, and lodging invoices. However, the exact timeline for when you can expect the reimbursement to be processed is not specified in the provided information. For precise details, you may need to consult the Business Travel Policy Manual or speak with your Line Manager or Department Head.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 102, 'prompt_tokens': 705, 'total_tokens': 807, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_c9a0e786b8', 'id': 'chatcmpl-ELAKfmqkT91AWidfeVo4zsHUeQZoS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--a652cc3d-2ff2-468d-ab46-cc6dacfe7b41-0' usage_metadata={'input_tokens': 705, 'output_tokens': 102, 'total_tokens': 807, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
