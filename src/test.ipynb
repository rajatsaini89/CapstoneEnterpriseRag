# %% [markdown]
# Testing the Doc Reader.py

# %%
import os

from modules.docReader import read_pdf, read_docx
from modules.textSplitter import split_documents
from modules.VectorStore import  addDocsToVectorStore,get_retriever
from utils.ConfigUtility import ConfigUtility

folderPath = '../Docs'


pdf_docs = read_docx(os.path.join(folderPath, 'abc_enterprise_travel_policy.docx'))

for doc in pdf_docs:
    print(doc.page_content[:50]+ '...')  # Print the first 50 characters of each PDF document

split_docs = split_documents(pdf_docs)

store = addDocsToVectorStore(split_docs)


ret = get_retriever(3)

docs =ret.invoke("How many total leaves are allowed in a year?")

for doc in docs:
    print(doc.page_content[:50]+ '...')  # Print the first 50 characters of each retrieved document

# %%
from modules.RagChain import build_chain
from modules.VectorStore import get_retriever





llm_chain = build_chain()
llm_chain.invoke(input={"question":"What are total number of leaves?",
                        "session_id": "test"}                      )
# while True:
#     ques = input("Enter Question")
#     if(ques == "quit"):
#         break
#     ans = llm_chain.invoke(
#             {   "question": "Give detailed explanation of Scikit-learn?"},
#     config = {"configurable": {"session_id": "abc"}},
#     )
#     print("Answer: {ans}")

# %%
from modules.BM25Retriever import BM25Retriever
from modules.docReader import load_all_docs
    
folderPath = '../Docs'
documents = load_all_docs(folderPath)

bm25Retriever = BM25Retriever(documents=documents)

results =bm25Retriever.get_top_k("What is the total enumeration", 2)

print(results)

# %%
from modules.RagChain import build_chain
from modules.VectorStore import get_retriever
from modules.chatMemory import llm_chain_with_memory

llm_chain = build_chain()
memory_chain = llm_chain_with_memory(llm_chain, enabled=True, recent_k=2)
resp1 = memory_chain.invoke(
    
     {   "question": "What are the total number of leaves?"},
      config={"configurable": {"session_id": "test_session_1"}})
print(resp1)
print("****************************************************************************")

response2 = memory_chain.invoke({"question":"As a Lead how much I can spend of hotel expenses during travel?"},
                       config={"configurable": {"session_id": "test_session_1"}})
print(response2)

print("****************************************************************************")

response3 = memory_chain.invoke({"question":"How many days I can expect for my expense reimbursement?"},
                       config={"configurable": {"session_id": "test_session_1"}})
print(response3)
# Out:
# e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.7.0) or chardet (7.6.0)/charset_normalizer (3.5.1) doesn't match a supported version!
#   warnings.warn(
# Building chain with LLM provider: openai, model: gpt-4o
# Hybrid RAG chain built successfully with provider: openai
# Adding memory to chain for session: test_session_1
# e:\IITPatnaProjects\CapStoneProject\src\modules\chatMemory.py:23: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   SESSION_SUMMARY_MEMORY[session_id] = ConversationSummaryMemory(
# Loading OpenAI embeddings...
# Updating existing FAISS
# using base retriever (simple similarity search)
# Generated context is [(Document(id='ce67ad0e-5e36-468f-8e1e-dcd55da40862', metadata={'page': 1, 'FileName': 'Docs\\abc_enterprise_leave_policy.pdf', 'chunk_index': 1}, page_content='operational continuity and adherence to statutory labor compliance. \n2. Leave Entitlements Summary\nLeave Category Annual\nQuota Accrual FrequencyKey Rules / Carry-Forward\nEarned / Privilege Leave\n(EL)\n18 Days 1.5 days / month Max 30 days carry-forward; encashable at\nseparation.\nCasual Leave (CL) 10 Days Credited annually\n(Jan 1)\nLapses at calendar year-end; cannot exceed 3\nconsecutive days.\nSick / Medical Leave\n(SL)\n8 Days Credited annually\n(Jan 1)\nRequires medical certificate if exceeding 2'), 0.6), (Document(metadata={'page': 2, 'FileName': 'Docs\\abc_enterprise_leave_policy.pdf'}, page_content='Note on Public Holidays: ABC Enterprise publishes an annual list of 10 mandatory and 2 optional (restricted) holidays at\nthe start of each calendar year. \n4. Leave Application & Approval Workflow\n1. Submission: Employee submits the leave request through the ABC Enterprise HR Portal / HRMS specifying\ndates and handover arrangements.\n2. Manager Review: Direct supervisor reviews the request within 48 business hours considering team coverage\nand project milestones.\n3. HR Record: Upon manager approval, the HRMS automatically updates the leave balance and notifies the payroll\ndepartment.\n5. General Terms & Non-Compliance\nUnplanned Absences: In emergencies, employees must notify their immediate supervisor via email or\nmessaging before 10:00 AM on the day of absence.\nLeave Without Pay (LWP): Leaves taken beyond accrued balances or without prior sanction will be classified as\nLWP, resulting in proportionate salary deduction.\nUnauthorized Absence: Continuous unnotified absence exceeding 5 consecutive working days will initiate\nstandard disciplinary procedures.\nPoC Disclaimer: This document is generated as a sample draft for evaluation and demonstration purposes for ABC\nEnterprise. \n• \n• \n• \nABC Enterprise • Corporate HR Policies • Strictly Internal Page 2 of 2'), 0.4), (Document(metadata={'paragraph': 18, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx'}, page_content='1. Domestic Trips (< $1,500 total estimated spend): Requires immediate Line Manager approval.'), 0.30000000000000004), (Document(id='0728f90e-bed6-4947-938c-43a6e83610d8', metadata={'page': 1, 'FileName': 'Docs\\abc_enterprise_leave_policy.pdf', 'chunk_index': 1}, page_content='operational continuity and adherence to statutory labor compliance. \n2. Leave Entitlements Summary\nLeave Category Annual\nQuota Accrual FrequencyKey Rules / Carry-Forward\nEarned / Privilege Leave\n(EL)\n18 Days 1.5 days / month Max 30 days carry-forward; encashable at\nseparation.\nCasual Leave (CL) 10 Days Credited annually\n(Jan 1)\nLapses at calendar year-end; cannot exceed 3\nconsecutive days.\nSick / Medical Leave\n(SL)\n8 Days Credited annually\n(Jan 1)\nRequires medical certificate if exceeding 2'), 0.22167086271951708), (Document(metadata={'paragraph': 19, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx'}, page_content='2. Domestic Trips (≥ $1,500 total spend): Requires Line Manager and Department Head (VP) approval.'), 0.20000000000000007)]
# content='Based on the retrieved context, the total number of leaves available annually at ABC Enterprise are as follows:\n\n1. Earned/Privilege Leave (EL): 18 days\n2. Casual Leave (CL): 10 days\n3. Sick/Medical Leave (SL): 8 days\n\nThis totals to 36 days of leave per year.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 809, 'total_tokens': 878, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_31fc60c16e', 'id': 'chatcmpl-EKjdMQ39EoZcKylXoNPpRlLo6kJDk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--985e4d66-5e02-456f-bdd4-2954b7ada53a-0' usage_metadata={'input_tokens': 809, 'output_tokens': 69, 'total_tokens': 878, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ****************************************************************************
# Adding memory to chain for session: test_session_1
# Loading OpenAI embeddings...
# Updating existing FAISS
# using base retriever (simple similarity search)
# Generated context is [(Document(id='f17b00c0-d7ca-4a79-b555-831d553506a5', metadata={'paragraph': 19, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='2. Domestic Trips (≥ $1,500 total spend): Requires Line Manager and Department Head (VP) approval.'), 0.6), (Document(id='b175e53b-8a0e-43c8-aa65-c58d79aa315a', metadata={'paragraph': 18, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='1. Domestic Trips (< $1,500 total estimated spend): Requires immediate Line Manager approval.'), 0.541061588392129), (Document(metadata={'paragraph': 10, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx'}, page_content='For domestic and international assignments, ABC Enterprise provides a standard daily meal allowance (per diem) to cover breakfast, lunch, dinner, and incidental expenses where meals are not hosted or provided by the company or client:'), 0.4), (Document(metadata={'paragraph': 24, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx'}, page_content='• Airport parking is covered for trips up to a maximum duration of 4 days.'), 0.30000000000000004), (Document(id='3e0020dc-8592-4ebd-a09c-6b41cd56cc37', metadata={'paragraph': 11, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='• Domestic Travel: Standard daily per diem of $75/day (Metros) or $55/day (Non-metros).'), 0.28259435862279464)]
# content="I'm sorry, but the retrieved context does not provide specific information about hotel expenses for a Lead during travel at ABC Enterprise. If you have any other questions or need further assistance, please let me know." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 601, 'total_tokens': 641, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_31fc60c16e', 'id': 'chatcmpl-EKjdSLi8meatX9JfaG7S0Q7cMwGig', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--56128b9e-03ac-41a4-b31c-f313427c4faa-0' usage_metadata={'input_tokens': 601, 'output_tokens': 40, 'total_tokens': 641, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ****************************************************************************
# Adding memory to chain for session: test_session_1
# Loading OpenAI embeddings...
# Updating existing FAISS
# using base retriever (simple similarity search)
# Generated context is [(Document(id='449f098f-befe-4847-9e24-e48dcc68a4fb', metadata={'paragraph': 26, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='All expense claims must be filed within 15 calendar days following return from travel. Required documentation includes itemized receipts for any individual expense item over $25, boarding passes, and lodging invoices detailing room rates and taxes.'), 0.6), (Document(metadata={'paragraph': 25, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx'}, page_content='6. Expense Settlement & Reimbursement Timeline'), 0.4), (Document(id='4a4a2dee-b202-43d2-8770-006022c9a3da', metadata={'paragraph': 25, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx', 'chunk_index': 0}, page_content='6. Expense Settlement & Reimbursement Timeline'), 0.30259397250278197), (Document(metadata={'paragraph': 26, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx'}, page_content='All expense claims must be filed within 15 calendar days following return from travel. Required documentation includes itemized receipts for any individual expense item over $25, boarding passes, and lodging invoices detailing room rates and taxes.'), 0.30000000000000004), (Document(metadata={'paragraph': 1, 'FileName': 'Docs\\abc_enterprise_travel_policy.docx'}, page_content='ABC ENTERPRISE • CORPORATE TRAVEL & EXPENSE POLICY'), 0.20000000000000007)]
# content='The retrieved context indicates that all expense claims must be filed within 15 calendar days following your return from travel. However, it does not provide specific information on how many days it will take for the reimbursement to be processed after filing. If you need further assistance or have other questions, please let me know.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 570, 'total_tokens': 631, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_31fc60c16e', 'id': 'chatcmpl-EKjdYcgkmM1x5hHytHO3DcQJiXRnN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--2880b54b-06f7-4b70-ad7d-fbd6d677647d-0' usage_metadata={'input_tokens': 570, 'output_tokens': 61, 'total_tokens': 631, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
