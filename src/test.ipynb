# %% [markdown]
# Testing the Doc Reader.py

# %%
import os

from modules.docReader import read_pdf, read_docx
from modules.textSplitter import split_documents
from modules.VectorStore import  addDocsToVectorStore,get_retriever
from utils.ConfigUtility import ConfigUtility

folderPath = '../Docs'


pdf_docs = read_docx(os.path.join(folderPath, 'abc_enterprise_travel_policy.docx'))

for doc in pdf_docs:
    print(doc.page_content[:50]+ '...')  # Print the first 50 characters of each PDF document

split_docs = split_documents(pdf_docs)

store = addDocsToVectorStore(split_docs)


ret = get_retriever(3)

docs =ret.invoke("How many total leaves are allowed in a year?")

for doc in docs:
    print(doc.page_content[:50]+ '...')  # Print the first 50 characters of each retrieved document

# %%
from modules.RagChain import build_chain
from modules.VectorStore import get_retriever





llm_chain = build_chain()
llm_chain.invoke(input={"question":"What are total number of leaves?",
                        "session_id": "test"}                      )
# while True:
#     ques = input("Enter Question")
#     if(ques == "quit"):
#         break
#     ans = llm_chain.invoke(
#             {   "question": "Give detailed explanation of Scikit-learn?"},
#     config = {"configurable": {"session_id": "abc"}},
#     )
#     print("Answer: {ans}")

# %%
from modules.BM25Retriever import BM25Retriever
from modules.docReader import load_all_docs
    
folderPath = '../Docs'
documents = load_all_docs(folderPath)

bm25Retriever = BM25Retriever(documents=documents)

results =bm25Retriever.get_top_k("What is the total enumeration", 2)

print(results)

# %%
from modules.RagChain import build_chain
from modules.VectorStore import get_retriever
from modules.chatMemory import llm_chain_with_memory

llm_chain = build_chain()
memory_chain = llm_chain_with_memory(llm_chain, enabled=True, recent_k=2)
resp1 = memory_chain.invoke(
    
     {   "question": "What are the total number of leaves?"},
      config={"configurable": {"session_id": "test_session_1"}})
print(resp1)
print("****************************************************************************")

response2 = memory_chain.invoke({"question":"As a Lead how much I can spend of hotel expenses during travel?"},
                       config={"configurable": {"session_id": "test_session_1"}})
print(response2)

print("****************************************************************************")

response3 = memory_chain.invoke({"question":"How many days I can expect for my expense reimbursement?"},
                       config={"configurable": {"session_id": "test_session_1"}})
print(response3)
# Out:
# e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.7.0) or chardet (7.6.0)/charset_normalizer (3.5.1) doesn't match a supported version!
#   warnings.warn(
# Building chain with LLM provider: openai, model: gpt-4o
# Hybrid RAG chain built successfully with provider: openai
# Adding memory to chain for session: test_session_1
# e:\IITPatnaProjects\CapStoneProject\src\modules\chatMemory.py:28: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   SESSION_SUMMARY_MEMORY[session_id] = ConversationSummaryMemory(
# Retrieving hybrid results for query: What are the total number of leaves??
# Loading OpenAI embeddings...
# Updating existing FAISS
# using multi-query retriever
# Using LLM provider: openai for multi-query retriever
# FAISS retrieved 6 documents for query: What are the total number of leaves??
# Loading documents from folder: e:\IITPatnaProjects\CapStoneProject\Docs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 7
#       3 from modules.chatMemory import llm_chain_with_memory
#       4
#       5 llm_chain = build_chain()
#       6 memory_chain = llm_chain_with_memory(llm_chain, enabled=True, recent_k=2)
# ----> 7 resp1 = memory_chain.invoke(
#       8
#       9      {   "question": "What are the total number of leaves?"},
#      10       config={"configurable": {"session_id": "test_session_1"}})
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)   5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)   5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)   5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:4772, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4758 """Invoke this Runnable synchronously.
#    4759
#    4760 Args:
#    (...)   4769     TypeError: If the Runnable is a coroutine function.
#    4770 """
#    4771 if hasattr(self, "func"):
# -> 4772     return self._call_with_config(
#    4773         self._invoke,
#    4774         input,
#    4775         ensure_config(config),
#    4776         **kwargs,
#    4777     )
#    4778 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4779 raise TypeError(msg)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:1940, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    1936     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1937     with set_config_context(child_config) as context:
#    1938         output = cast(
#    1939             "Output",
# -> 1940             context.run(
#    1941                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1942                 func,
#    1943                 input_,
#    1944                 config,
#    1945                 run_manager,
#    1946                 **kwargs,
#    1947             ),
#    1948         )
#    1949 except BaseException as e:
#    1950     run_manager.on_chain_error(e)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:4641, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4637         msg = (
#    4638             f"Recursion limit reached when invoking {self} with input {input_}."
#    4639         )
#    4640         raise RecursionError(msg)
# -> 4641     output = output.invoke(
#    4642         input_,
#    4643         patch_config(
#    4644             config,
#    4645             callbacks=run_manager.get_child(),
#    4646             recursion_limit=recursion_limit - 1,
#    4647         ),
#    4648     )
#    4649 return cast("Output", output)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)   5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:4772, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4758 """Invoke this Runnable synchronously.
#    4759
#    4760 Args:
#    (...)   4769     TypeError: If the Runnable is a coroutine function.
#    4770 """
#    4771 if hasattr(self, "func"):
# -> 4772     return self._call_with_config(
#    4773         self._invoke,
#    4774         input,
#    4775         ensure_config(config),
#    4776         **kwargs,
#    4777     )
#    4778 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4779 raise TypeError(msg)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:1940, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    1936     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1937     with set_config_context(child_config) as context:
#    1938         output = cast(
#    1939             "Output",
# -> 1940             context.run(
#    1941                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1942                 func,
#    1943                 input_,
#    1944                 config,
#    1945                 run_manager,
#    1946                 **kwargs,
#    1947             ),
#    1948         )
#    1949 except BaseException as e:
#    1950     run_manager.on_chain_error(e)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:4630, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4628                 output = chunk
#    4629 else:
# -> 4630     output = call_func_with_variable_args(
#    4631         self.func, input_, config, run_manager, **kwargs
#    4632     )
#    4633 # If the output is a Runnable, invoke it
#    4634 if isinstance(output, Runnable):
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File e:\IITPatnaProjects\CapStoneProject\src\modules\chatMemory.py:78, in llm_chain_with_memory.<locals>.chain_with_summary(input_data, config)
#      73 print(f"Adding memory to chain for session: {session_id}")
#      74 summary_memory = getSessionSummaryMemory(session_id)
# ---> 78 response = chain.invoke({"question":f"{input_data.get('question')}?",
#      79                 "session_id": config.get("configurable", {}).get("session_id")}               )
#      80 user_input = input_data.get("question")
#      81 ai_output = getattr(response, "content",str(response))
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:3045, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3043 with set_config_context(config) as context:
#    3044     if i == 0:
# -> 3045         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046     else:
#    3047         input_ = context.run(step.invoke, input_, config)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:3774, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3769     with get_executor_for_config(config) as executor:
#    3770         futures = [
#    3771             executor.submit(_invoke_step, step, input, config, key)
#    3772             for key, step in steps.items()
#    3773         ]
# -> 3774         output = {key: future.result() for key, future in zip(steps, futures)}
#    3775 # finish the root run
#    3776 except BaseException as e:
#
# File C:\Python312\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File C:\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File C:\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:3758, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3752 child_config = patch_config(
#    3753     config,
#    3754     # mark each step as a child run
#    3755     callbacks=run_manager.get_child(f"map:key:{key}"),
#    3756 )
#    3757 with set_config_context(child_config) as context:
# -> 3758     return context.run(
#    3759         step.invoke,
#    3760         input_,
#    3761         child_config,
#    3762     )
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:4772, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4758 """Invoke this Runnable synchronously.
#    4759
#    4760 Args:
#    (...)   4769     TypeError: If the Runnable is a coroutine function.
#    4770 """
#    4771 if hasattr(self, "func"):
# -> 4772     return self._call_with_config(
#    4773         self._invoke,
#    4774         input,
#    4775         ensure_config(config),
#    4776         **kwargs,
#    4777     )
#    4778 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4779 raise TypeError(msg)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:1940, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    1936     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1937     with set_config_context(child_config) as context:
#    1938         output = cast(
#    1939             "Output",
# -> 1940             context.run(
#    1941                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1942                 func,
#    1943                 input_,
#    1944                 config,
#    1945                 run_manager,
#    1946                 **kwargs,
#    1947             ),
#    1948         )
#    1949 except BaseException as e:
#    1950     run_manager.on_chain_error(e)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\base.py:4630, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4628                 output = chunk
#    4629 else:
# -> 4630     output = call_func_with_variable_args(
#    4631         self.func, input_, config, run_manager, **kwargs
#    4632     )
#    4633 # If the output is a Runnable, invoke it
#    4634 if isinstance(output, Runnable):
#
# File e:\IITPatnaProjects\CapStoneProject\.venv\Lib\site-packages\langchain_core\runnables\config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File e:\IITPatnaProjects\CapStoneProject\src\modules\HybridRetriever.py:45, in retrieve_documents(query)
#      42 print(f"FAISS retrieved {len(faiss_Docs)} documents for query: {query}")
#      44 folderPath = os.path.join(Path(__file__).parent.parent.parent, "Docs")
# ---> 45 documents = load_all_docs(folderPath)
#      47 bm25_retriever_instance = BM25Retriever(documents)
#      48 bm25Results = bm25_retriever_instance.get_top_k(query)
#
# File e:\IITPatnaProjects\CapStoneProject\src\modules\docReader.py:17, in load_all_docs(folder_path)
#      15     docs.extend(read_pdf(path))
#      16 elif file.lower().endswith('.docx'):
# ---> 17     docs.extend(read_docx(path))
#      18 elif file.lower().endswith('.txt'):
#      19     docs.extend(read_txt(path))
#
# File e:\IITPatnaProjects\CapStoneProject\src\modules\docReader.py:53, in read_docx(file_path)
#      51 doc = docx.Document(file_path)
#      52 documents = []
# ---> 53 for i, paragraph in enumerate(doc.pages):
#      54     text = paragraph.text
#      55     if text:
#
# AttributeError: 'Document' object has no attribute 'pages'
